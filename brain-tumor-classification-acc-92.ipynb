# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        os.path.join(dirname, filename)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## Import The Libraries

# %%
import keras
from keras.models import Sequential
from keras.layers import Conv2D,Flatten,Dense,MaxPooling2D,Dropout
from sklearn.metrics import accuracy_score

# %%
import ipywidgets as widgets
import io
from PIL import Image
import tqdm
from sklearn.model_selection import train_test_split
import cv2
from sklearn.utils import shuffle
import tensorflow as tf

# %% [markdown]
# ## Folder Paths

# %%
X_train = []
Y_train = []
image_size = 150
labels = ['glioma_tumor','meningioma_tumor','no_tumor','pituitary_tumor']
for i in labels:
    folderPath = os.path.join('../input/brain-tumor-classification-mri/Training',i)
    for j in os.listdir(folderPath):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        Y_train.append(i)
        

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# %%
X_train,Y_train = shuffle(X_train,Y_train,random_state=101)
X_train.shape
# Out:
# (2870, 150, 150, 3)

# %% [markdown]
# ## Training & Building & Complie The NN

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,Y_train,test_size=0.1,random_state=101)

# %%
y_train_new = [labels.index(i) for i in y_train]
y_train = tf.keras.utils.to_categorical(y_train_new, num_classes=4)

y_test_new = [labels.index(i) for i in y_test]
y_test = tf.keras.utils.to_categorical(y_test_new, num_classes=4)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(4, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 146, 146, 64)      18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 73, 73, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 73, 73, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 71, 71, 64)        36928
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 69, 69, 64)        36928
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 69, 69, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 34, 34, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 34, 34, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 128)       147584
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 12, 12, 128)       147584
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 10, 10, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3277312
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 4,447,044
# Trainable params: 4,447,044
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train,epochs=50,validation_split=0.1)
# Out:
# Epoch 1/50
# 73/73 [==============================] - 12s 51ms/step - loss: 2.0471 - accuracy: 0.2939 - val_loss: 1.3586 - val_accuracy: 0.2973
# Epoch 2/50
# 73/73 [==============================] - 3s 39ms/step - loss: 1.3472 - accuracy: 0.3201 - val_loss: 1.3498 - val_accuracy: 0.3127
# Epoch 3/50
# 73/73 [==============================] - 3s 39ms/step - loss: 1.1578 - accuracy: 0.4604 - val_loss: 0.9904 - val_accuracy: 0.6448
# Epoch 4/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.9024 - accuracy: 0.6153 - val_loss: 0.8842 - val_accuracy: 0.5985
# Epoch 5/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.7770 - accuracy: 0.6497 - val_loss: 0.7749 - val_accuracy: 0.6564
# Epoch 6/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.6425 - accuracy: 0.7281 - val_loss: 0.6631 - val_accuracy: 0.7375
# Epoch 7/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.5600 - accuracy: 0.7676 - val_loss: 0.6476 - val_accuracy: 0.7181
# Epoch 8/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.5546 - accuracy: 0.7586 - val_loss: 0.6138 - val_accuracy: 0.7954
# Epoch 9/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.4632 - accuracy: 0.8090 - val_loss: 0.4787 - val_accuracy: 0.8108
# Epoch 10/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.3492 - accuracy: 0.8580 - val_loss: 0.5098 - val_accuracy: 0.8378
# Epoch 11/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.3152 - accuracy: 0.8868 - val_loss: 0.5114 - val_accuracy: 0.8224
# Epoch 12/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.2455 - accuracy: 0.9028 - val_loss: 0.4644 - val_accuracy: 0.8687
# Epoch 13/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.2635 - accuracy: 0.9019 - val_loss: 0.4080 - val_accuracy: 0.8919
# Epoch 14/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.1860 - accuracy: 0.9260 - val_loss: 0.5654 - val_accuracy: 0.8301
# Epoch 15/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.1848 - accuracy: 0.9294 - val_loss: 0.4697 - val_accuracy: 0.8803
# Epoch 16/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.1584 - accuracy: 0.9423 - val_loss: 0.5692 - val_accuracy: 0.8417
# Epoch 17/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.1573 - accuracy: 0.9492 - val_loss: 0.4545 - val_accuracy: 0.8842
# Epoch 18/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.1198 - accuracy: 0.9565 - val_loss: 0.4709 - val_accuracy: 0.8571
# Epoch 19/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.1381 - accuracy: 0.9531 - val_loss: 0.4739 - val_accuracy: 0.8919
# Epoch 20/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.1116 - accuracy: 0.9613 - val_loss: 0.3433 - val_accuracy: 0.8958
# Epoch 21/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0870 - accuracy: 0.9720 - val_loss: 0.5155 - val_accuracy: 0.8842
# Epoch 22/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0976 - accuracy: 0.9651 - val_loss: 0.5609 - val_accuracy: 0.8803
# Epoch 23/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0884 - accuracy: 0.9664 - val_loss: 0.6212 - val_accuracy: 0.8494
# Epoch 24/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0718 - accuracy: 0.9725 - val_loss: 0.7075 - val_accuracy: 0.9112
# Epoch 25/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0479 - accuracy: 0.9815 - val_loss: 0.5915 - val_accuracy: 0.9073
# Epoch 26/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0700 - accuracy: 0.9776 - val_loss: 0.5787 - val_accuracy: 0.8958
# Epoch 27/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0815 - accuracy: 0.9729 - val_loss: 0.7114 - val_accuracy: 0.9112
# Epoch 28/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0672 - accuracy: 0.9828 - val_loss: 0.4507 - val_accuracy: 0.8958
# Epoch 29/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0483 - accuracy: 0.9849 - val_loss: 0.5519 - val_accuracy: 0.8996
# Epoch 30/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0738 - accuracy: 0.9738 - val_loss: 0.8165 - val_accuracy: 0.8842
# Epoch 31/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0389 - accuracy: 0.9905 - val_loss: 0.9405 - val_accuracy: 0.8842
# Epoch 32/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0642 - accuracy: 0.9815 - val_loss: 0.7849 - val_accuracy: 0.8571
# Epoch 33/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0974 - accuracy: 0.9712 - val_loss: 0.5244 - val_accuracy: 0.8842
# Epoch 34/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0854 - accuracy: 0.9725 - val_loss: 0.6283 - val_accuracy: 0.8842
# Epoch 35/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0929 - accuracy: 0.9712 - val_loss: 0.5257 - val_accuracy: 0.8958
# Epoch 36/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0412 - accuracy: 0.9849 - val_loss: 0.7131 - val_accuracy: 0.8842
# Epoch 37/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0551 - accuracy: 0.9845 - val_loss: 0.5716 - val_accuracy: 0.8919
# Epoch 38/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0379 - accuracy: 0.9888 - val_loss: 0.5538 - val_accuracy: 0.9073
# Epoch 39/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.1070 - accuracy: 0.9677 - val_loss: 0.4628 - val_accuracy: 0.8996
# Epoch 40/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0352 - accuracy: 0.9858 - val_loss: 0.7934 - val_accuracy: 0.8726
# Epoch 41/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0727 - accuracy: 0.9832 - val_loss: 0.4929 - val_accuracy: 0.9189
# Epoch 42/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0461 - accuracy: 0.9880 - val_loss: 0.3594 - val_accuracy: 0.9073
# Epoch 43/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0237 - accuracy: 0.9923 - val_loss: 0.5419 - val_accuracy: 0.8726
# Epoch 44/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0272 - accuracy: 0.9905 - val_loss: 0.5942 - val_accuracy: 0.9073
# Epoch 45/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0411 - accuracy: 0.9888 - val_loss: 0.6754 - val_accuracy: 0.8996
# Epoch 46/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0407 - accuracy: 0.9871 - val_loss: 0.6681 - val_accuracy: 0.8919
# Epoch 47/50
# 73/73 [==============================] - 3s 39ms/step - loss: 0.0269 - accuracy: 0.9918 - val_loss: 0.8245 - val_accuracy: 0.8726
# Epoch 48/50
# 73/73 [==============================] - 3s 38ms/step - loss: 0.0407 - accuracy: 0.9858 - val_loss: 0.6955 - val_accuracy: 0.9073
# Epoch 49/50
# 73/73 [==============================] - 3s 38ms/step - loss: 0.0444 - accuracy: 0.9836 - val_loss: 0.7052 - val_accuracy: 0.8842
# Epoch 50/50
# 73/73 [==============================] - 3s 38ms/step - loss: 0.0268 - accuracy: 0.9892 - val_loss: 0.6355 - val_accuracy: 0.9112

# %%
y_pred=model.predict(X_test)

# %%
print(y_pred)
y_pred_indices = np.argmax(y_pred, axis=1)
print('=======================================================')
print(y_pred_indices)
# Out:
# [[6.0524252e-11 3.2862622e-11 1.0000000e+00 6.6174677e-16]
#  [1.2511280e-09 1.7044346e-07 3.3317275e-07 9.9999952e-01]
#  [4.4586234e-13 3.4233892e-06 9.9999654e-01 1.4711115e-13]
#  ...
#  [7.8876861e-09 2.4634238e-07 9.9999976e-01 9.9938460e-11]
#  [9.5268043e-13 7.1178384e-08 7.8097634e-10 9.9999988e-01]
#  [6.5351577e-07 6.9371231e-02 4.5612769e-06 9.3062353e-01]]
# =======================================================
# [2 3 2 3 1 0 3 3 3 0 1 0 0 0 3 2 3 3 2 1 3 0 0 0 1 2 1 0 3 1 0 1 0 1 1 3 0
#  2 0 2 0 1 0 0 0 2 1 0 1 1 0 1 3 3 0 0 3 3 0 3 0 3 2 3 2 3 0 3 0 1 3 0 1 3
#  0 3 2 3 0 0 0 1 1 3 2 0 1 0 0 2 0 3 3 0 3 2 2 3 0 1 0 2 0 2 3 1 3 3 0 2 1
#  3 2 1 1 1 0 0 2 2 3 2 0 3 3 1 1 0 2 3 3 1 1 2 1 3 3 3 0 1 3 0 0 0 1 0 2 0
#  1 0 3 0 1 0 0 1 1 2 1 2 0 3 0 0 1 0 3 3 3 3 3 1 0 3 3 1 0 2 3 1 0 3 0 0 0
#  1 2 2 2 0 0 3 0 1 0 3 0 1 1 3 3 3 3 1 0 0 0 3 0 3 3 1 3 2 2 0 3 0 0 2 3 1
#  0 3 0 0 0 1 0 3 3 0 3 1 0 0 1 1 2 1 3 0 1 2 3 1 3 0 0 0 0 1 3 0 0 3 2 0 0
#  2 3 2 2 3 3 0 3 0 0 1 1 0 1 1 2 0 0 2 3 0 1 3 2 0 2 3 3]

# %%
y_test_indices = np.argmax(y_test, axis=1)

# %%
accuracy = accuracy_score(y_test_indices, y_pred_indices)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.9233

# %% [markdown]
# ## Result Visiulaization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test_indices,y_pred_indices, labels=range(len(labels)))

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
#model.save('braintumor.v1')

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(len(acc))
fig = plt.figure(figsize=(14,7))
plt.plot(epochs,acc,'r',label="Training Accuracy")
plt.plot(epochs,val_acc,'b',label="Validation Accuracy")
plt.legend(loc='upper left')
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(loss))
fig = plt.figure(figsize=(14,7))
plt.plot(epochs,loss,'r',label="Training loss")
plt.plot(epochs,val_loss,'b',label="Validation loss")
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Prediction

# %%
img = cv2.imread('/kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(109).jpg')
img = cv2.resize(img,(150,150))
img_array = np.array(img)
img_array.shape
# Out:
# (150, 150, 3)

# %%
img_array = img_array.reshape(1,150,150,3)
img_array.shape
# Out:
# (1, 150, 150, 3)

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img('/kaggle/input/brain-tumor-classification-mri/Testing/meningioma_tumor/image(109).jpg')
plt.imshow(img,interpolation='nearest')
plt.show()

# %%
predictor = model.predict(img_array)
index = predictor.argmax()

# Map index to label
labels = ["Glioma", "Meningioma", "No Tumor", "Pituitary"]
tumor_type = labels[index]



# Display the image with the predicted label
plt.imshow(img)
plt.title(tumor_type)
plt.axis('off')
plt.show()
